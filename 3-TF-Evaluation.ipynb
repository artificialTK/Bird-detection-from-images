# %%
# Set model path
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"
# PATH_TO_MODEL = "ssd_resnet50_v1_fpn_1024x1024_coco17_tpu-8"

# %%
# !CUDA_VISIBLE_DEVICES="-1" python model_main_tf2.py --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --model_dir=training/TF2/training/{PATH_TO_MODEL} --checkpoint_dir=training/TF2/training/{PATH_TO_MODEL} --alsologtostderr
# Out:
# 2023-01-06 07:43:54.193838: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0106 07:43:55.445356 139887331369792 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0106 07:43:55.445438 139887331369792 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0106 07:43:55.445477 139887331369792 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0106 07:43:55.445514 139887331369792 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %%
# Import the necessary modules
import matplotlib.pyplot as plt
import glob

# Use glob to get a list of all image files in a directory
image_files = glob.glob('faster_rcnn_result/*.png')

# Loop through the list of image files
for image_file in image_files:
    # Load the image using matplotlib
    image = plt.imread(image_file)

    # Display the image
    plt.imshow(image)
    plt.show()

# %% [markdown]
# the faster rcnn modeel results are displayed above as you can see the model is performing extremely well with an 0.5 and 0.75 IOU of 0.83 and 0.59 and the training loss is slightly below than validation loss which indicates that the trained model is a good model. I choose this modeel because this modeel is insensitive to the training input image resolution and gives the best results for detecting small objects in an image such as birds. upon first training the model was overfitting and to eliminate that issue I implemented regularization with a weight of 0.1 and the model waas not overfitting anymore.

# %%
#PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"
PATH_TO_MODEL = "ssd_resnet50_v1_fpn_1024x1024_coco17_tpu-8"

# %%
# !CUDA_VISIBLE_DEVICES="-1" python model_main_tf2.py --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --model_dir=training/TF2/training/{PATH_TO_MODEL} --checkpoint_dir=training/TF2/training/{PATH_TO_MODEL} --alsologtostderr
# Out:
# 2023-01-09 05:45:17.778321: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0109 05:45:19.182654 139779026326336 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0109 05:45:19.182738 139779026326336 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0109 05:45:19.182780 139779026326336 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0109 05:45:19.182816 139779026326336 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %%
# Use glob to get a list of all image files in a directory
image_files = glob.glob('ssd_result/*.png')

# Loop through the list of image files
for image_file in image_files:
    # Load the image using matplotlib
    image = plt.imread(image_file)

    # Display the image
    plt.imshow(image)
    plt.show()

# %% [markdown]
# the results above are of the model trained on ssd resnet 1024x1024 the results are explaining that the model is not performing well as in the past report with theory I mentioned that the ssd model is sensitive to resizing the images and requires the input images to be of the same resolution as the output images hence the results justify the theory explained. Moreover upon inferencing there were no detections from the test set of this model
