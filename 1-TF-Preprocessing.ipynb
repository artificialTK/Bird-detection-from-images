# %% [markdown]
# # Data Tagging

# %% [markdown]
# ### Data Resoultion Analyser

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import numpy as np
import pandas as pd

# %%
# !python xml_to_csv.py --verbose
# Out:
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Erithacus_Rubecula_974.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Periparus_ater_936.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Erithacus_Rubecula_791.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Erithacus_Rubecula_512.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Pica_pica354.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Pica_pica899.xml
# /home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/CW2_regularized_15.1K/images/train/Periparus_ater_1083.xml
# ...

# %%
data = pd.read_csv('./data/train_labels.csv') # lodaing the file from the directory

# %%
data.head() # reading the data columns and rows to know the dimensions of the data
# Out:
#                      filename   width  height              class        xmin  \
# 0  Erithacus_Rubecula_974.jpg  1024.0  1024.0  ErithacusRubecula  242.638239
# 1      Periparus_ater_936.jpg  1024.0   683.0      PeriparusAter  307.613535
# 2  Erithacus_Rubecula_791.jpg  1000.0   700.0  ErithacusRubecula  380.348412
# 3  Erithacus_Rubecula_512.jpg   768.0  1024.0  ErithacusRubecula  352.697501
# 4            Pica_pica354.jpg  1024.0   768.0          Pica_pica  380.454607
#
#          ymin        xmax         ymax
# 0  214.185131  903.169985  1023.517984
# 1  272.536032  584.499821   464.687595
# 2  263.110552  578.117435   502.347273
# 3  361.799043  395.160021   408.616693
# 4  245.210830  486.457205   418.901834

# %%
data.describe().transpose() # this command leads to see the description of data for a better understanding of the data
# Out:
#          count        mean         std         min         25%          50%  \
# width   2710.0  942.416605  147.222912  162.000000  900.000000  1024.000000
# height  2710.0  783.025092  155.002759  216.000000  683.000000   768.000000
# xmin    2710.0  332.031676  141.751499    0.000000  231.700573   341.179234
# ymin    2710.0  278.340416  120.618893    0.000000  194.038451   268.150445
# xmax    2710.0  602.545002  166.756540   82.881048  491.449677   592.988624
# ymax    2710.0  528.583672  146.533955  116.362697  429.118952   518.900583
#
#                 75%          max
# width   1024.000000  1024.000000
# height   888.750000  1024.000000
# xmin     428.985917   955.242322
# ymin     344.827730   799.323910
# xmax     709.575503  1024.000000
# ymax     611.643507  1024.000000

# %%
data['class'].value_counts()
# Out:
# Pica_pica            940
# PeriparusAter        901
# ErithacusRubecula    869
# Name: class, dtype: int64

# %%
dim1 = []
dim2 = []
for image_filename in os.listdir('./images'):
    name, ext = os.path.splitext(image_filename)
    try:
        if not ext == '.xml':
            img = imread('./images/'+image_filename)
            d1,d2,color = img.shape
            dim1.append(d1)
            dim2.append(d2)
            
    except: 
        print(image_filename)
        continue

# %%
sns.jointplot(dim1,dim2)
# Out:
# /home/msc1/anaconda3/envs/Env-7144COMP/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.show()

# %%
np.mean(dim1)
# Out:
# 785.6881906077348

# %%
print('Min:', np.min(dim1))
print('Max:', np.max(dim1))
# Out:
# Min: 216
# Max: 1024

# %%
np.mean(dim2)
# Out:
# 943.0673342541437

# %%
print('Min:', np.min(dim2))
print('Max:', np.max(dim2))
# Out:
# Min: 162
# Max: 1024

# %% [markdown]
# ## 1) Clean the XML - This will create a new directory under ./images called cleaned. Once script is run copy the contents back to /images overwriting the existing xml

# %%
# !python xmlconversion.py --verbose
# Out:
# images/Erithacus_Rubecula_974.xml
# images/Periparus_ater_936.xml
# images/Erithacus_Rubecula_791.xml
# images/Erithacus_Rubecula_512.xml
# images/Pica_pica354.xml
# images/Periparus_ater_1050.xml
# images/Pica_pica899.xml
# images/Periparus_ater_1083.xml
# images/Pica_pica510.xml
# images/Pica_pica641.xml
# images/Periparus_ater_973.xml
# images/Pica_pica418.xml
# images/Erithacus_Rubecula_181.xml
# images/Pica_pica256.xml
# images/Periparus_ater_985.xml
# images/Pica_pica190.xml
# images/Erithacus_Rubecula_97.xml
# images/Erithacus_Rubecula_218.xml
# images/Periparus_ater_1230.xml
# images/Periparus_ater_46.xml
# images/Erithacus_Rubecula_170.xml
# images/Erithacus_Rubecula_800.xml
# images/Erithacus_Rubecula_238.xml
# images/Periparus_ater_1079.xml
# images/Erithacus_Rubecula_514.xml
# images/Pica_pica647.xml
# images/Pica_pica554.xml
# images/Erithacus_Rubecula_46.xml
# images/Erithacus_Rubecula_337.xml
# images/Pica_pica735.xml
# images/Pica_pica316.xml
# ...

# %% [markdown]
# ## Patition the train / test split 90/10

# %%
# !python partition_dataset.py -x -i ./images -r 0.1
